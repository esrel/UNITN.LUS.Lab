# %% [markdown]
# # Statistical Language Modeling
#
# - Language Understanding Systems
# - Evgeny A. Stepanov
# - stepanov.evgeny.a@gmail.com

# %% [markdown]
# ## Introduction
#
# This notebook is part of the Laboratory Work for [Language Understanding Systems class](http://disi.unitn.it/~riccardi/page7/page13/page13.html) of [University of Trento](https://www.unitn.it/en).
# Laboratory has been ported to jupyer notebook format for remote teaching during [COVID-19 pandemic](https://en.wikipedia.org/wiki/2019%E2%80%9320_coronavirus_pandemic).
#
# This notebook covers Lecture on __Sequence and Language Modeling__.
#
# Dan Jurafsky and James H. Martin's __Speech and Language Processing__ ([3rd ed. draft](https://web.stanford.edu/~jurafsky/slp3/)) is adviced for reading.
#
# - Section *Corpora and Counting* covers some conceptes of *Chapter 2: "Regular Expressions, Text Normalization, Edit Distance"*.
# - Sections *Ngrams and Ngram Probabilites* and *Language Models* roughly cover *Chapter 3: "N-gram Language Models"*.
#
# <span style="color: blue;">__NOTE__</span>:
#
# Due to popularity of Python as a programming language for Natural Langauge Processing and Machine Learning, the exercises use Python (occassionally Unix Shell).
# Prefer to avoid using libraries, unless exlicitly stated (e.g. don't use [`Counter`](https://docs.python.org/3/library/collections.html#collections.Counter)).

# %% [markdown]
# ## Requirements
#
# - [NL2SparQL4NLU](https://github.com/esrel/NL2SparQL4NLU) dataset
#
#     - run `git clone https://github.com/esrel/NL2SparQL4NLU.git`

# %% [markdown]
# ## 1. Corpora and Counting

# %% [markdown]
# ### 1.1. Corpus
#
# [Corpus](https://en.wikipedia.org/wiki/Text_corpus) is a collection of written or spoken texts that is used for language research. Before doing anything with a corpus we need to know its properties:
#
# __Corpus Properties__:
# - *Format* -- how to read/load it?
# - *Language* -- which tools/models can I use?
# - *Annotation* -- what it is intended for?
# - *Split* for __Evaluation__: (terminology varies from source to source)
#
# | Set         | Purpose                                       |
# |:------------|:----------------------------------------------|
# | Training    | training model, extracting rules, etc.        |
# | Development | tuning, optimization, intermediate evaluation |
# | Test        | final evaluation (remains unseen)             |

# %% [markdown]
# #### NL2SparQL4NLU
#
# - __Format__:
#
#     - Utterance (sentence) per line
#     - Tokenized
#     - Lowercased
#
# - __Language__: English monolingual
#
# - __Annotation__: None (for now)
#
# - __Split__: training & test sets

# %% [markdown]
# #### Exercise
#
# - define a function to load a corpus into a list-of-lists
#
# - load `NL2SparQL4NLU/dataset/NL2SparQL4NLU.train.utterances.txt`
# - print first `2` words (tokens) of the first `10` sentences

# %%
trn='NL2SparQL4NLU/dataset/NL2SparQL4NLU.train.utterances.txt'
tst='NL2SparQL4NLU/dataset/NL2SparQL4NLU.test.utterances.txt'

# %% [markdown]
# ### 1.2. Corpus Descriptive Statistics (Counting)
#
# *Corpus* description in terms of:
#
# - total number of words
# - total number of utterances

# %% [markdown]
# #### Exercise
#
# - define a function to compute corpus descriptive statistics -- total utterance and word counts.
# - compute the statistics for the __training__ and __test__ sets of NL2SparQL4NLU dataset.
# - compare the computed statistics with the reference values below.
#
#
# | Metric           | Train  | Test   |
# |------------------|-------:|-------:|
# | Total Words      | 21,453 |  7,117 |
# | Total Utterances |  3,338 |  1,084 |

# %% [markdown]
# ### 1.3. Lexicon
#
# [Lexicon](https://en.wikipedia.org/wiki/Lexicon) is the *vocabulary* of a language. In linguistics, a lexicon is a language's inventory of lexemes.
#
# Linguistic theories generally regard human languages as consisting of two parts: a lexicon, essentially a catalogue of a language's words; and a grammar, a system of rules which allow for the combination of those words into meaningful sentences.
#
# *Lexion (or Vocabulary) Size* is one of the statistics reported for corpora. While *Word Count* is the number of __tokens__, *Lexicon Size* is the number of __types__ (unique words).

# %% [markdown]
# #### Exercise
#
# - define a function to compute a lexicon from corpus in a list-of-lists format
#     - sort the list alphabetically
#
# - compute the lexicon of the training set of NL2SparQL4NLU dataset
# - compare the its size to the reference value below.
#
# | Metric       | Value |
# |--------------|------:|
# | Lexicon Size | 1,729 |

# %% [markdown]
# ### 1.4. Frequency List
#
# In Natural Language Processing (NLP), [a frequency list](https://en.wikipedia.org/wiki/Word_lists_by_frequency) is a sorted list of words (word types) together with their frequency, where frequency here usually means the number of occurrences in a given corpus, from which the rank can be derived as the position in the list.
#
# What is a "word"?
#
# - case sensitive counts
# - case insensitive counts (our corpus is lowercased)

# %% [markdown]
# #### Exercise
#
# - define a function to compute a frequency list for a corpus
# - compute frequency list for the training set of NL2SparQL4NLU dataset
# - report `5` most frequent words (use can use provided `nbest` function to get a dict of top N items)
# - compate the frequencies to the reference values below
#
# | Word   | Frequency |
# |--------|----------:|
# | the    |     1,337 |
# | movies |     1,126 |
# | of     |       607 |
# | in     |       582 |
# | movie  |       564 |

# %%
def nbest(d, n=1):
    """
    get n max values from a dict
    :param d: input dict (values are numbers)
    :param n: number of values to get (int)
    :return: dict of top n key-values
    """
    return dict(sorted(d.items(), key=lambda item: item[1], reverse=True)[:n])

# %% [markdown]
# ### 1.5. Lexicon Operations
#
# It is common to process the lexicon according to the task at hand (not every transformation makes sense for all tasks). The common operations are removing words by frequency (minimum or maximum, i.e. *Frequency Cut-Off*) and removing words for a specific lists (i.e. *Stop Word Removal*).
#
# In computing, [stop words](https://en.wikipedia.org/wiki/Stop_words) are words which are filtered out before or after processing of natural language data (text). Though "stop words" usually refers to the most common words in a language, there is no single universal list of stop words used by all natural language processing tools, and indeed not all tools even use such a list. Some tools specifically avoid removing these stop words to support phrase search.
#
# Any group of words can be chosen as the stop words for a given purpose.

# %% [markdown]
# #### Exercises

# %% [markdown]
# ##### Frequency Cut-Off
#
# - define a function to compute a lexicon from a frequency list applying minimum and maximum frequency cut-offs
#
#     - use default values for min and max
#
# - using frequency list for the training set of NL2SparQL4NLU dataset
#
#     - compute lexicon applying:
#
#         - minimum cut-off 2 (remove words that appear less than 2 times, i.e. remove [hapax legomena](https://en.wikipedia.org/wiki/Hapax_legomenon))
#         - maximum cut-off 100 (remove words that appear more that 100 times)
#         - both minimum and maximum thresholds together
#
#     - report size for each comparing to the reference values in the table
#
# | Operation  | Min | Max | Size |
# |------------|----:|----:|-----:|
# | original   | N/A | N/A | 1729 |
# | cut-off    |   2 | N/A |  950 |
# | cut-off    | N/A | 100 | 1694 |
# | cut-off    |   2 | 100 |  915 |

# %% [markdown]
# ##### Stop Word Removal
#
# - define a function to read/load a list of words in token-per-line format (i.e. lexicon)
# - load stop word list from `NL2SparQL4NLU/extras/english.stop.txt`
# - using Python's built it `set` [methods](https://docs.python.org/2/library/stdtypes.html#set):
#
#     - define a function to compute overlap of two lexicons
#     - define a function to apply a stopword list to a lexicon
#
# - compare the 100 most frequent words in frequency list of the training set to the list of stopwords (report count)
# - apply stopword list to the lexicon of the training set
# - report size of the resulting lexicon comparing to the reference values.
#
# | Operation       | Size |
# |-----------------|-----:|
# | original        | 1729 |
# | no stop words   | 1529 |
# | top 100 overlap |   50 |

# %%
swl='NL2SparQL4NLU/extras/english.stop.txt'

# %% [markdown]
# ### <span style="color: blue;">Solutions</span>

# %% [markdown]
# #### Function Definitions

# %%
def read_corpus(corpus_file):
    """
    read corpus into a list-of-lists, splitting sentences into tokens by space (' ')
    :param corpus_file: corpus file in sentence-per-line format (tokenized)
    :return: corpus as list of lists
    """
    return [line.strip().split() for line in open(corpus_file, 'r')]

def read_lexicon(lexicon_file):
    """
    read lexicon into a list
    :param lexicon_file: lexicon file in token-per-line format
    :return: lexicon as a list
    """
    return [line.strip() for line in open(lexicon_file, 'r')]

def compute_lexicon(corpus):
    """
    compute lexicon of a corpus
    :param corpus: corpus as list-of-lists
    :return: sorted list of unique words
    """
    return sorted(list(set([word for sent in corpus for word in sent])))

def compute_frequency_list(corpus):
    """
    create frequency list for a corpus
    :param corpus: corpus in list-of-lists format
    :return: frequency list as dict of counts
    """
    frequencies = {}
    for sentence in corpus:
        for token in sentence:
            frequencies[token] = frequencies.setdefault(token, 0) + 1 
    return frequencies

def nbest(d, n=1):
    """
    get n top values from a dict
    :param d: input dict (values are numbers)
    :param n: number of values to get (int)
    :return: dict of top n key-values
    """
    return dict(sorted(d.items(), key=lambda item: item[1], reverse=True)[:n])

def cutoff(frequency_list, tf_min=1, tf_max=float('inf')):
    """
    apply min and max cutoffs to a frequency list
    :param frequency_list: frequency list of a corpus as dict
    :param tf_min: minimum token frequency for lexicon elements (below removed); default 1
    :param tf_max: maximum token frequency for lexicon elements (above removed); default infinity
    :return: lexicon as sorted list of tokens
    """
    return sorted([token for token, frequency in frequency_list.items() if tf_max >= frequency >= tf_min])

def compute_overlap(a, b):
    """
    compute overal of two lists as set intersection
    :param a: list 1
    :param b: list 2
    :return: sorted list of overlapping elements
    """
    return sorted(list(set(a) & set(b)))
    
def remove_stopwords(lexicon, stopwords):
    """
    remove stopwords from a lexicon
    :param lexicon: lexicon as a list
    :param stopwords: stopwords list
    :return: sorted difference of two lists (lexicon - stopwords)
    """
    return sorted(list(set(lexicon) - set(stopwords)))

def corpus_stats(corpus):
    """
    compute word and sentence counts of the corpus
    :param corpus: corpus as list-of-lists
    :return: sentence count, word count
    """
    return len(corpus), sum([len(sent) for sent in corpus])

# %% [markdown]
# #### Set paths to data set files

# %%
trn = 'NL2SparQL4NLU/dataset/NL2SparQL4NLU.train.utterances.txt'
tst = 'NL2SparQL4NLU/dataset/NL2SparQL4NLU.test.utterances.txt'
swl = 'NL2SparQL4NLU/extras/english.stop.txt'

# %% [markdown]
# #### Corpus Reading & Iterating

# %%
corpus = read_corpus(trn)

for sentence in corpus[:10]:
    print(sentence[:2])
# Out:
# ['who', 'plays']
# ['show', 'credits']
# ['who', 'was']
# ['find', 'the']
# ['who', 'played']
# ['who', 'was']
# ['who', 'played']
# ['who', 'was']
# ['find', 'the']
# ['cast', 'and']

# %% [markdown]
# #### Corpus Statistics

# %%
print(corpus_stats(read_corpus(trn)))
print(corpus_stats(read_corpus(tst)))
# Out:
# (3338, 21453)
# (1084, 7117)

# %% [markdown]
# #### Computing Lexicon & Its Size

# %%
lex = compute_lexicon(corpus)
print(len(lex))
# Out:
# 1729

# %% [markdown]
# #### Computing Frequency List

# %%
freq_list = compute_frequency_list(corpus)
print(nbest(freq_list, n=5))
# Out:
# {'the': 1337, 'movies': 1126, 'of': 607, 'in': 582, 'movie': 564}

# %% [markdown]
# #### Applying Cut-Off & Reporting Lexicon Sizes

# %%
print(len(cutoff(freq_list)))
print(len(cutoff(freq_list, tf_min=2)))
print(len(cutoff(freq_list, tf_max=100)))
print(len(cutoff(freq_list, tf_min=2, tf_max=100)))
# Out:
# 1729
# 950
# 1694
# 915

# %% [markdown]
# #### Computing Lexicon Overlap (Set Intersection)

# %%
stopwords = read_lexicon(swl)
top_words = list(nbest(freq_list, n=100).keys())
print(len(compute_overlap(top_words, stopwords)))
# Out:
# 50

# %% [markdown]
# #### Removing Stopwords (Set Difference)

# %%
print(len(remove_stopwords(lex, stopwords)))
# Out:
# 1529

# %% [markdown]
# ## 2. Ngrams and Ngram Probabilities

# %% [markdown]
# [n-gram](https://en.wikipedia.org/wiki/N-gram) is a contiguous sequence of *n* items from a given sequence of text or speech. An n-gram model models sequences, notably natural languages, using the statistical properties of n-grams.
#
# __Example__:
#
# - character n-grams: cat
# - word n-grams: the cat is fat
#
#
# |                     | 1-gram  | 2-gram  | 3-gram  |
# |---------------------|---------|---------|---------|
# |                     | unigram | bigram  | trigram |
# | *Markov Order*      | 0       | 1       | 2       |
# | *Character N-grams* | `['c', 'a', 't']` | `['ca', 'at']` | `['cat']` |
# | *Word N-grams*      | `['the', 'cat', 'is' , 'fat']` | `['the cat', 'cat is', ...]` | `['the cat is', ...]` |

# %% [markdown]
# ### 2.1. Counting Ngrams
#
# *Frequency List* of a corpus is essentially a unigram count. Ngram count only differs in a unit of counting -- sequence of $n$ of words. We can compute bigram count by taking sequences of 2 items, trigrams - 3, etc.

# %% [markdown]
# #### 2.1.1. Data Structures
# For *Frequency List* we have used [`dict`](https://docs.python.org/2/library/stdtypes.html#dict) to store counts.
# In ngram counting scenario we still can use dictionary, and use ngram string keys; however, there are better data structures for the task. The frequent data structures used to store ngram counts or probabilities are [hash table](https://en.wikipedia.org/wiki/Hash_table), [trie](https://en.wikipedia.org/wiki/Trie), or [finite state automaton](https://en.wikipedia.org/wiki/Deterministic_acyclic_finite_state_automaton). The pros and cons of each data structure are out of the scope of this lab; for the discussion on efficient data structures for language modeling please refer to [KenLM paper](https://kheafield.com/papers/avenue/kenlm.pdf).

# %% [markdown]
# #### 2.1.2. Implementing Trie
# There are plenty of implementation of the Trie data structure (e.g. [`pygtrie`](https://github.com/google/pygtrie/) from Google). However, it is simple enough.
#
# For understanding purposes let's implement our own, such that:
#
# - works on lists of words
# - stores in a node word, count, and children (`Node` class)
# - implements methods to:
#     - add a sequence (updating counts)
#     - get a node by a sequence (i.e. prefix)
#     - set a node attribute given sequence, key and value
#     - traverse a trie and get all sequences
#
# It is convenient to introduce an `error` node to the Trie to easily handle sequences not in it.
# Thus, we also add `self.error` with `count` set to $0$.

# %%
class Node(object):

    def __init__(self, word=None):
        self.word = word
        self.children = {}
        self.count = 0
        
    def __set__(self, instance, value):
        self.instance = value

    def __get__(self, instance, owner):
        return self.instance


class Trie(object):
    
    def __init__(self):
        self.root = Node('*')
        self.error = Node()
    
    # convenient to set and get values (e.g. model metadata)
    def __set__(self, instance, value):
        self.instance = value

    def __get__(self, instance, owner):
        return self.instance

    def add(self, sequence):
        node = self.root
        node.count += 1  # total count
        for word in sequence:
            node.children[word] = node.children.setdefault(word, Node(word))
            node = node.children[word]
            node.count += 1

    def get(self, sequence):
        node = self.root
        for word in sequence:
            if not node.children:
                return self.error
            elif not word in node.children:
                return self.error
            else:
                node = node.children.get(word)
        return node
    
    def traverse(self, node=None, sequence=[]):
        node = self.root if not node else node
        
        if not node.children:
            yield sequence

        for word, n in node.children.items():
            sequence.append(word)
            yield from self.traverse(n, sequence)
            sequence.pop()

# %% [markdown]
# ##### Testing out the implementation...

# %%
counts = Trie()
counts.add(['a', 'b', 'c', 'd'])
counts.add(['a', 'e', 'c', 'f'])

counts.size = 4

tests = [['a'], ['a', 'b'], ['a', 'x']]

for seq in tests:
    print(counts.get(seq).count)

for seq in counts.traverse():
    print(seq)
    
print(counts.size)
# Out:
# 2
# 1
# 0
# ['a', 'b', 'c', 'd']
# ['a', 'e', 'c', 'f']
# 4

# %% [markdown]
# #### Exercise
#
# - define a function to extract ngrams (variable $n$) from a sequence (sentence) represented as a list
# - define a function to compute ngram counts from a corpus (list-of-lists) and store as a Trie
# - compute bigram counts for the training set of NL2SparQL4NLU
# - report `5` most frequent bigrams comparing to the reference values below (you can use `nbest` on `node.children`)
#
#
#  word 1 | word 2 | count
# :-------|:-------|-------:
# show    | me     |   377
# the     | movie  |   267
# of      | the    |   186
# me      | the    |   122
# is      | the    |   120

# %% [markdown]
# ### 2.2. Computing Ngram Probabilities

# %% [markdown]
# #### 2.2.1. Calculating Probability from Frequencies
#
# Probabilities of ngrams can be computed *normalizing* frequency counts (*Maximum Likelihood Estimation*): dividing the frequency of an ngram sequence by the frequency of its prefix (*relative frequency*).
#
# N-gram   | Equation
# :--------|:------------------------------
# Unigram  | $$p(w_i) = \frac{c(w_i)}{N}$$
# Bigram   | $$p(w_i | w_{i-1}) = \frac{c(w_{i-1}, w_i)}{c(w_{i-1})}$$
# Ngram    | $$p(w_i | w_{i-n+1}^{i-1}) = \frac{c(w_{i-n+1}^{i-1}, w_i)}{c(w_{i-n+1}^{i-1})}$$
#
# where:
# - $N$ is the total number of words in a corpus
# - $c(x)$ is the count of occurences of $x$ in a corpus (x could be unigram, bigram, etc.)

# %% [markdown]
# ##### Exercise
#
# - define a function to compute ngram probabilities using ngram counts
#
# - compute probabilities of ngrams ($n=2$) in the training set of NL2SparQL4NLU
# - report probabilities of the following ngrams
#     - $p(the | of)$
#     - $p(the | is)$
#     - $p(play | the)$
#     - probabilities of all bigram where $w_1$ is "*italy*", i.e. $p(*|italy)$

# %% [markdown]
# #### 2.2.2. Underflow Problem
#
# Probabilities are usually small ($<1$).
# Multiplying many of those may cause *underflow* problem.
#
# Use the sum of the probabilities' logs instead of product
#
# | Properties
# |:---------------
# | $$p(a) > p(b)$$
# | $$log(p(a)) > log(p(b))$$
# | $$log(a*b) = log(a) + log(b)$$
# | $$p(a) * p(b) \rightarrow log(p(a)) + log(p(b))$$

# %% [markdown]
# ##### Exercise
# - update the function to compute probabilities to use log (use `math` library)
# - define a function to convert log probabilities to probabilities (`exp()`)

# %% [markdown]
# ### <span style="color: blue;">Solutions</span>

# %% [markdown]
# #### Function Definitions

# %%
def ngrams(sequence, n=2):
    """
    returns ngrams as a list-of-lists of sequence elements
    :param sequence: list of elements
    :param n: ngram size to extract
    :return: list of ngrams
    """
    return [sequence[i:i+n] for i in range(len(sequence) - n + 1)]

def ngramcount(corpus, n=2):
    """
    count ngrams in a corpus and stores as a Trie
    :param corpus: list-of-lists
    :param n: ngram size to count
    :param glue: symbol for ngram concatenation into string
    :return: dict of ngram frequencies
    """
    counts = Trie()
    counts.size = n  # meta-info: ngram-size
    for sent in corpus:
        for ngram in ngrams(sent, n=n):
            counts.add(ngram) 
    return counts

def ngramprobs(counts, logs=True):
    """
    compute ngram probabilities from frequency counts
    :param counts: counts trie
    :param logs: if to compute log-probabilities
    :return: trie augmented with probabilties
    """
    from math import log
    
    # update default values:
    counts.error.probability = 0.0  # set error node probability to 0
    counts.logs = logs  # meta-info: log probabilities are used
    
    for ngram in counts.traverse(): 
        n = counts.get(ngram)       # get ngram node
        p = counts.get(ngram[:-1])  # get parent node
        prob = n.count / p.count
        n.probability = log(prob) if logs else prob
    return counts

def logp2p(value):
    from math import exp
    return exp(value) if value else 0.0

# %% [markdown]
# #### Counting ngrams & Reporting most frequent

# %%
counts = ngramcount(corpus, n=2)

print(nbest({"+".join(ngram): counts.get(ngram).count for ngram in counts.traverse()}, n=5))
# Out:
# {'show+me': 377, 'the+movie': 267, 'of+the': 186, 'me+the': 122, 'is+the': 120}

# %% [markdown]
# #### Computing Probabilities & Querying Ngrams

# %%
raw_probs = ngramprobs(counts, logs=False)

print(raw_probs.get(['of', 'the']).probability)
print(raw_probs.get(['is', 'the']).probability)
print(raw_probs.get(['the', 'play']).probability)  # not in training data

for ngram in raw_probs.traverse(node=raw_probs.get(['italy']), sequence=['italy']):
    print(ngram, raw_probs.get(ngram).probability)
    
# testing logp2p
log_probs = ngramprobs(counts)

print(logp2p(log_probs.get(['of', 'the']).probability))
print(logp2p(log_probs.get(['is', 'the']).probability))
print(logp2p(log_probs.get(['the', 'play']).probability))  # not in training data
# Out:
# 0.30642504118616143
# 0.36363636363636365
# 0.0
# ['italy', 'make'] 0.5
# ['italy', 'in'] 0.5
# 0.30642504118616143
# 0.36363636363636365
# 0.0

# %% [markdown]
# ## 3. Using Ngram Language Models
#
# A statistical [language model](https://en.wikipedia.org/wiki/Language_model) is a probability distribution over sequences of words. Given such a sequence, say of length $n$, it assigns a probability $p(w_{1},\ldots ,w_{n})$ ($p(w_{1}^{n})$, for compactness) to the whole sequence (using Chain Rule). Consequently, the unigram and bigram probabilities computed above constitute an ngram language model of our corpus.
#
# It is more useful for Natural Language Processing to have a __probability__ of a sequence being legal, rather than a grammar's __boolean__ decision whether it is legal or not.

# %% [markdown]
# ### 3.1. Computing Probability of a Sequence (Scoring)
#
# The most common usage of a language model is to compute probability of a sequence.

# %% [markdown]
# #### 3.1.1. Probability of a Sequence: [Chain Rule](https://en.wikipedia.org/wiki/Chain_rule_(probability))
#
# Probability of a sequence is computed as a product of conditional probabilities (chain rule).
#
# $$p(w_{1}^{n}) = p(w_1) p(w_2|w_1) p(w_3|w_1^2) ... p(w_n|w_{1}^{n-1}) = \prod_{i=1}^{n}{p(w_i|w_{1}^{i-1})}$$
#
# The order of ngram makes a simplifying assumption that probability of a current word only depends on previous $N - 1$ elements. Thus, it truncates previous context (history) to length $N - 1$.
#
# $$p(w_i|w_{1}^{i-1}) \approx p(w_i|w_{i-N+1}^{i-1})$$
#
# Consequently we have:
#
# N-gram   | Equation                   |
# :--------|:---------------------------|
# unigram  | $$p(w_i)$$                 |
# bigram   | $$p(w_i|w_{i-1})$$         |
# trigram  | $$p(w_i|w_{i-2},w_{i-1})$$ |
#
# The probability of the whole sequence applying an ngram model becomes:
#
# $$p(w_{1}^{n}) = \prod_{i=1}^{n}{p(w_i|w_{i-N+1}^{i-1})}$$

# %% [markdown]
# #### 3.1.2. Sentence beginning & end tags
#
# Including sentence boundary markers leads to a better model. To do that we need to augment each sentence with a special symbols for beginning and end of sentence tags (`<s>` and `</s>`, respectively). The beginning of the sentence tag gives the bigram context of the first word; and encodes probability of a word to start a sentence. Adding the end of the sentence tag, on the other hand, makes the bigram model a true probability distribution (Jurafsky and Martin). "Without it, the sentence probabilities for all sentences of a given length would sum to one. This model would define an infinite set of probability distributions, with one distribution per sentence length."
#
# For larger ngrams, we’ll need to assume extra context for the contexts to the left and right of the sentence boundaries. For example, to compute trigram probabilities at the very beginning of the sentence, we can use two pseudo-words for the first trigram (i.e. `['<s>', '<s>', w1]`). Alternatively, we can use [back-off](https://en.wikipedia.org/wiki/Katz%27s_back-off_model), and use the `['<s>', w1]` bigram probability.

# %% [markdown]
# __Example__: "The cat is fat"
#
# $$p(\langle s \rangle, the, cat, is, fat, \langle /s \rangle) =$$
# $$= p(the | \langle s \rangle) * p(cat | the) * p(is | cat) * p(fat | is) * p(\langle /s \rangle | fat) = $$
# $$= 0.25 * 0.10 * 0.20 * 0.05 * 0.15 = 0.0000375$$

# %% [markdown]
# ##### Exercise
# - define a function to add sentence beginning and end tags to a corpus as list-of-lists
# - define a function to compute sentence probability given an ngram model
#     - remember that for log we use sum for raw probabilities product
#         - use `math.prod` for Python 3.8
#         - use `numpy.prod` for Python < 3.8
# - re-compute bigram probabilities for the training set of NL2SparQL4NLU
# - compute probability of sentences: *star of twilight* and *star of thor*

# %% [markdown]
# ### 3.2. Generating Sequences
#
# Ngram Model can be used as an automaton to generate probable legal sequences using the algorithm below.
#
# __Algorithm for Bigram LM__
#
# - $w_{i-1} = \langle s \rangle$;
# - *while* $w_i \neq \langle /s \rangle$
#
#     - stochastically get new word w.r.t. $p(w_i|w_{i-1})$

# %% [markdown]
# #### Exercise
# - define a function to generate random sentences (e.g. using `random.choice`)
# - generate `5` different sentences & score them

# %% [markdown]
# ### 3.3. Evaluation: [Perplexity](https://en.wikipedia.org/wiki/Perplexity)
#
# - Measures how well model fits test data
# - Probability of test data
# - Weighted average branching factor in predicting the next word (lower is better).
# - Computed as:
#
# $$ PPL = \sqrt[N]{\frac{1}{p(w_1,w_2,...,w_N)}} = \sqrt[N]{\frac{1}{\prod_{i=1}^{N}p(w_i|w_{i-N+1})}}$$
#
# Where $N$ is the number of words in test set.

# %% [markdown]
# ### <span style="color: blue;">Solutions</span>

# %% [markdown]
# #### Defined Functions

# %%
def corpus_add_tags(corpus, bos='<s>', eos='</s>'):
    """
    add beginning-of-sentence (bos) and end-of-sentence (eos) tags
    :param corpus: corpus as list-of-lists
    :param bos: beginning-of-sentence tag
    :param eos: end-of-sentence tag
    """
    return [[bos] + sent + [eos] for sent in corpus]

def score(model, sentence):
    """
    score a sentence given ngram model
    :param model: trie ngram model
    :param sentence: sentence as a list of tokens
    :return: log probability
    """
    from numpy import prod
    probs = [model.get(ngram).probability for ngram in ngrams(sentence, model.size)]
    return sum(probs) if model.logs else prod(probs)
    
def generate(model, bos='<s>', eos='</s>'):
    """
    generate a random sequence from ngram model
    :param model: trie ngram model
    :param bos: beginning-of-sentence tag
    :param eos: end-of-sentence tag
    :return: sentence as list & log probability
    """
    import random
    word = bos
    sent = [bos]
    while word != eos:
        c_node = model.get(sent[-(model.size - 1):])
        word = random.choice(list(c_node.children.keys()))
        sent.append(word)
    return sent

# %% [markdown]
# #### Scoring Sentences

# %%
# tag corpus
tagged_corpus = corpus_add_tags(corpus)

# re-build ngram model
tagged_counts = ngramcount(tagged_corpus, n=2)
tagged_probs = ngramprobs(tagged_counts)

# sentence adding tags
sent1 = corpus_add_tags([['star', 'of', 'twilight']])[0]
sent2 = corpus_add_tags([['star', 'of', 'thor']])[0]

print(score(tagged_probs, sent1))
print(score(tagged_probs, sent2))
# Out:
# -15.643604864128623
# -9.609769522510536

# %% [markdown]
# #### Generating Sentences

# %%
for i in range(5):
    s = generate(tagged_probs)
    print("({:5.2f}): {}".format(score(tagged_probs, s), " ".join(s)))
# Out:
# (-10.60): <s> gross overall </s>
# (-8.11): <s> auqua fish </s>
# (-16.13): <s> which company for pulp fiction </s>
# (-10.95): <s> zombie apocolypse </s>
# (-25.03): <s> italian movies he was amazing </s>

# %% [markdown]
# ### 3.4. Handling Unseen Words
#
# Out-Of-Vocabulary (OOV) word -- tokens in test data that are not contained in the lexicon (vocabulary).
# Empirically each OOV word results in 1.5 - 2 extra errors (> 1 due to the loss of contextual information).
#
# __*How to handle words (in test set) that were never seen in the training data?*__
#
# Train a language model with specific token (e.g. `<unk>`) for unknown words!
#
# __*How to estimate probabilities of unknown words and ngrams?*__
#
# The *simplest* approach is to replace all the words that are not in vocabulary (lexicon) with the `<unk>` token and treat it as any other word. (For instance, applying frequency cut-off to the lexicon, will allow estimate these probabilities on the training set.)

# %% [markdown]
# #### Exercise
# - define a function to replace OOV words in a corpus as list-of-list given a lexicon
# - re-compute bigram probabilities for the training set of NL2SparQL4NLU (with `<unk>`)
# - re-compute probability of sentences: *star of twilight* and *star of thor*
#     - replace unknown words and add tags as well
# - compare scores to the ones without unknown word handling

# %% [markdown]
# #### <span style="color: blue;">Solutions</span>

# %% [markdown]
# #### Defined Functions

# %%
def corpus_replace_oov(corpus, lexicon, unk='<unk>'):
    """
    replace all tokens that are not in lexicon with unk
    :param corpus: corpus as list-of-lists
    :param lexicon: lexicon as a list of tokens
    :return: processed corpus
    """
    return [[token if token in lexicon else unk for token in sent] for sent in corpus]

# %% [markdown]
# #### Replacing OOV & re-scoring

# %%
# replace unknown corpus
unk_lexicon = cutoff(compute_frequency_list(tagged_corpus), tf_min=2)
unk_corpus = corpus_replace_oov(tagged_corpus, unk_lexicon)

# re-build ngram model
unk_counts = ngramcount(unk_corpus, n=2)
unk_probs = ngramprobs(unk_counts)

# sentence adding tags
sent1 = corpus_replace_oov(corpus_add_tags([['star', 'of', 'twilight']]), unk_lexicon)[0]
sent2 = corpus_replace_oov(corpus_add_tags([['star', 'of', 'thor']]), unk_lexicon)[0]

print(score(unk_probs, sent1))
print(score(unk_probs, sent2))
# Out:
# -15.643604864128623
# -13.731498255275248

# %% [markdown]
# ### 3.6. Handling Data Sparseness
#
# What do we do with words that are in our lexicon, but appear in a test set in an unseen context (i.e. no ngram)?
#
# Similar to unseen words and unseen n-grams have $0$ probability; thus, whole sequence gets $0$ probability.
# (The problem is somewhat avoided using log probabilities.)
#
# Use smoothing:
# - Add some probability to unseen events
# - Remove some probability from seen events
# - Joint probability distribution sums to 1!

# %% [markdown]
# ##### Smoothing Methods
#
# Available smoothing methods: ([tutorial](https://nlp.stanford.edu/~wcmac/papers/20050421-smoothing-tutorial.pdf))
# - [Additive smoothing](https://en.wikipedia.org/wiki/Additive_smoothing) (__simplest__)
# - Good-Turing estimate
# - Jelinek-Mercer smoothing (interpolation)
# - Katz smoothing (backoff)
# - Witten-Bell smoothing
# - Absolute discounting
# - Kneser-Ney smoothing

# %% [markdown]
# #### 3.6.1. Add-One Smoothing
# Kind of Additive Smoothing.
#
# __Bigrams__
#
# $V$ -- vocabulary size
#
# $$p(w_i | w_{i-1}) = \frac{c(w_{i-1},w_i)+1}{c(w_{i-1})+V}$$
#
# __N-grams__
#
# $V$ -- total number of possible $(N-1)$-grams
#
# $$p(w_i | w^{i-1}_{i-N+1}) = \frac{c(w^{i-1}_{i-N+1},w_i)+1}{c(w^{i-1}_{i-N+1})+V}$$
#
# Typically, we assume $V = \{w : c(w) > 0\} \cup \{<unk>\}$

# %% [markdown]
# #### Exercise
# - update the ngram probability calculation function to apply add one smoothing
# - re-compute bigram probabilities for the training set of NL2SparQL4NLU with smoothing
# - compare scores to the ones without smoothing

# %% [markdown]
# #### <span style="color: blue;">Solutions</span>

# %% [markdown]
# #### Defined Functions

# %%
def compute_ngram_vocabulary_size(counts, n=1):
    return len(set(["+".join(ngram[:n]) for ngram in counts.traverse()]))

def ngramprobs(counts, logs=True, smoothing=False):
    """
    compute ngram probabilities from frequency counts
    :param counts: counts trie
    :param logs: if to compute log-probabilities
    :param smoothing: if to use add 1 smoothing
    :return: trie augmented with probabilties
    """
    from math import log
    
    # set meta-information
    counts.logs = logs  # meta-info: log probabilities are used
    counts.smoothing = smoothing # meta-info: smoothing true|false
    
    # add 1 smoothing
    v = compute_ngram_vocabulary_size(counts, n = counts.size - 1) if smoothing else 0
    a = 1 if smoothing else 0
    
    # update error probability:
    counts.error.probability = log(a / v) if (smoothing and logs) else 0.0
    
    for ngram in counts.traverse(): 
        n = counts.get(ngram)       # get ngram node
        p = counts.get(ngram[:-1])  # get parent node
        prob = (n.count + a) / (p.count + v)
        n.probability = log(prob) if logs else prob
    return counts

# %%
# re-build ngram model
sm_probs = ngramprobs(unk_counts, smoothing=True)

# sentence adding tags
sent1 = corpus_replace_oov(corpus_add_tags([['star', 'of', 'twilight']]), unk_lexicon)[0]
sent2 = corpus_replace_oov(corpus_add_tags([['star', 'of', 'thor']]), unk_lexicon)[0]

print(score(unk_probs, sent1))
print(score(unk_probs, sent2))
# Out:
# -23.038581629648416
# -17.936125948586973

# %% [markdown]
# ### 3.7. Putting it all together (Exercise)
#
# Train an Ngram Language Model (compute ngram probabilities) such that:
#
# - case insensitive (by default)
# - 2-gram
# - log probabilities
# - considers sentence boundaries (beginning and end of sentence tags)
# - considers unknown words
# - Add-One Smoothing
#
# Compute probabilties of utterances in `NL2SparQL4NLU/dataset/NL2SparQL4NLU.test.utterances.txt`

# %% [markdown]
# #### <span style="color: blue;">Solution</span>

# %%
trn='NL2SparQL4NLU/dataset/NL2SparQL4NLU.train.utterances.txt'
tst='NL2SparQL4NLU/dataset/NL2SparQL4NLU.test.utterances.txt'

trn_data_raw = read_corpus(trn)
trn_data_tag = corpus_add_tags(trn_data_raw)

# make lexicon
lex = cutoff(compute_frequency_list(tagged_corpus), tf_min=2)

trn_data_unk = corpus_replace_oov(trn_data_tag, lex)

# re-build ngram model
counts = ngramcount(trn_data_unk, n=2)
probs = ngramprobs(counts, logs=True, smoothing=True)

# prepare test set
tst_data_raw = read_corpus(tst)
tst_data_tag = corpus_add_tags(tst_data_raw)
tst_data_unk = corpus_replace_oov(tst_data_tag, lex)

for sent in tst_data_unk:
    print("({:5.2f}): {}".format(score(probs, sent), " ".join(sent)))
# Out:
# (-17.94): <s> star of <unk> </s>
# (-27.43): <s> who is in the movie the campaign </s>
# (-34.34): <s> list the cast of the movie the campaign </s>
# (-21.80): <s> who was in twilight </s>
# (-16.45): <s> who is in <unk> </s>
# (-17.64): <s> actor from lost </s>
# (-15.91): <s> who played in the movie rocky </s>
# (-32.10): <s> who played in the movie captain america </s>
# (-29.33): <s> cast and crew for in july </s>
# (-27.05): <s> who is in movie in july </s>
# (-39.19): <s> who 's in star wars episode four </s>
# (-24.22): <s> who was in apollo thirteen </s>
# (-22.52): <s> who was apollo thirteen 's cast </s>
# (-48.00): <s> search for information about the cast and crew of <unk> thirteen </s>
# (-62.58): <s> i would like to know more about the cast and crew of the movie apollo thirteen </s>
# (-22.86): <s> who starred in the avengers </s>
# (-21.89): <s> cast for finding nemo </s>
# (-18.44): <s> actor from <unk> </s>
# (-21.89): <s> list actors in the movie <unk> <unk> </s>
# (-14.24): <s> dirty dancing actors </s>
# (-30.96): <s> who are cast and crew of dirty dancing </s>
# (-18.96): <s> who was in hitch </s>
# (-32.26): <s> who is in the cast of hitch </s>
# (-29.55): <s> star of facts of life </s>
# (-15.46): <s> show me movie credits </s>
# (-28.52): <s> who does the <unk> for the movie </s>
# (-18.93): <s> find movie actors </s>
# (-13.91): <s> show credits - forager </s>
# (-28.66): <s> star of <unk> family </s>
# (-40.17): <s> look up information about the cast crew of go </s>
# (-41.67): <s> find information about the cast and crew of go </s>
# (-34.78): <s> who was in the cast of go </s>
# (-46.59): <s> can you find the lead actor in pretty women </s>
# (-34.02): <s> what are the actors names and <unk> in finding nemo </s>
# (-55.90): <s> searching for names of crew members of <unk> thirteen </s>
# (-23.60): <s> budget for dark knight </s>
# (-26.51): <s> what was the budget for the godfather </s>
# (-19.56): <s> budget for twilight </s>
# (-40.79): <s> please look up the budget of step up </s>
# (-18.74): <s> budget for titanic the movie </s>
# (-28.73): <s> what was the budget for the movie titanic </s>
# (-18.47): <s> budget for iron man 2 </s>
# (-37.66): <s> please tell me how much was the budget for avatar </s>
# (-44.28): <s> how much money did they spend to make avatar </s>
# (-20.90): <s> avatar 's budget </s>
# (-24.40): <s> how much did avatar take in </s>
# (-40.07): <s> please show me what the budget was for avatar </s>
# (-31.34): <s> what was the budget for the avatar movie </s>
# (-35.41): <s> can you tell me the budget of the movie avatar </s>
# (-28.30): <s> total budget for the movie avatar </s>
# (-33.02): <s> what was the budget for batman begins </s>
# (-25.97): <s> what was the budget for the avengers </s>
# (-36.07): <s> what was the budget for gone with the wind </s>
# (-41.47): <s> what was <unk> on my big fat greek wedding </s>
# (-19.31): <s> what was pretty woman 's budget </s>
# (-20.08): <s> what was the budget for <unk> </s>
# (-38.77): <s> how many movies has kevin bacon been the lead actor in </s>
# (-29.36): <s> how many star wars movies are there </s>
# (-26.48): <s> how many movies are rated g </s>
# (-8.91): <s> spain has how many movies </s>
# (-30.87): <s> how many movies has kristen stewart starred in </s>
# (-28.33): <s> how many movies has robert wise directed </s>
# (-33.70): <s> how many movies did alfred hitchcock direct </s>
# (-18.87): <s> how many movies has paramount done </s>
# (-64.88): <s> i would like to know the name of the country from where the movie kati patang comes </s>
# (-17.41): <s> what country is <unk> </s>
# (-19.95): <s> what country made black swan </s>
# (-23.90): <s> what country was black swan from </s>
# (-24.96): <s> what country was the movie made </s>
# (-37.02): <s> what country did <unk> <unk> <unk> come from </s>
# (-23.45): <s> origin of titanic </s>
# (-14.55): <s> origin of king <unk> </s>
# (-19.23): <s> when will top gun be released </s>
# (-15.19): <s> release year and date for <unk> </s>
# (-27.62): <s> when did will ferrell <unk> <unk> </s>
# (-31.41): <s> show me when 24 will be released </s>
# (-26.24): <s> can i have release date of movie </s>
# (-25.90): <s> movie 's release date </s>
# (-32.58): <s> show me when the movie was made </s>
# (-24.74): <s> when the movie titanic was released </s>
# (-37.55): <s> what year did the italian movie <unk> <unk> come out </s>
# (-51.04): <s> can you please search for release date for karate kid </s>
# (-26.55): <s> karate kid release date please </s>
# (-24.10): <s> when was dirty dancing released </s>
# (-20.47): <s> when was <unk> released </s>
# (-9.81): <s> when was batman released </s>
# (-15.30): <s> when was pretty woman released </s>
# (-25.96): <s> when was men in black released </s>
# (-14.21): <s> when did kristen stewart start <unk> </s>
# (-31.41): <s> when is <unk> going to be released </s>
# (-19.95): <s> when was resident evil released </s>
# (-23.07): <s> release date for finding nemo </s>
# (-23.36): <s> when was finding nemo released </s>
# (-28.74): <s> release date of hum tum </s>
# (-14.48): <s> when was freedom writers released </s>
# (-20.26): <s> when was avatar released </s>
# (-21.91): <s> when did avatar released </s>
# (-42.75): <s> i would like to know the release date of the movie avatar </s>
# (-38.20): <s> can you tell me when was the movie avatar released </s>
# (-9.81): <s> when was date night released </s>
# (-25.78): <s> when did black swan come out </s>
# (-28.04): <s> when did <unk> come out </s>
# (-43.30): <s> what date did the amazing spiderman show for the 1st time </s>
# (-31.00): <s> what is the release date of vulgaria </s>
# (-28.19): <s> when the movie the godfather was released </s>
# (-24.67): <s> when does looper come out </s>
# (-43.13): <s> can you tell me the release date of the movie barfi </s>
# (-33.91): <s> what date did the movie heroine come out </s>
# (-56.78): <s> when did the house at the end of the street <unk> theaters </s>
# (-18.52): <s> what day is fun <unk> coming out </s>
# (-12.72): <s> genre for bad <unk> </s>
# (-38.96): <s> can you tell me pretty girl the movie 's genre </s>
# (-31.72): <s> what genre is the movie <unk> perfect </s>
# (-29.03): <s> in what language is this movie </s>
# (-20.10): <s> what language is this movie </s>
# (-23.51): <s> what language is the movie hero in </s>
# (-11.96): <s> language of king <unk> </s>
# (-18.76): <s> language of <unk> <unk> </s>
# (-29.00): <s> what language is <unk> on in </s>
# (-15.98): <s> language of <unk> </s>
# (-55.81): <s> find out what language the father of my children is in </s>
# (-49.82): <s> i am <unk> in <unk> belle what foreign language is the movie available in </s>
# (-43.95): <s> i need to find out about names of some japanese movies </s>
# (-37.73): <s> can you tell me names of some japanese movies </s>
# (-35.26): <s> ron howard name some of the movies he produce </s>
# (-49.45): <s> tell me the names of the movies produced by william packer </s>
# (-21.34): <s> about life is beautiful </s>
# (-27.32): <s> show me info on life is beautiful </s>
# (-10.78): <s> find old movies </s>
# (-18.41): <s> find movie ratings </s>
# (-31.58): <s> find <unk> released movies in spanish </s>
# (-30.15): <s> was bill paxton in the movie apollo thirteen </s>
# (-42.01): <s> was kevin bacon in the movie apollo thirteen </s>
# (-17.45): <s> find movies about dancing </s>
# (-21.93): <s> search for movies about dancing </s>
# (-20.27): <s> show will ferrell films </s>
# (-15.84): <s> will ferrell movies </s>
# (-26.20): <s> what movies has will ferrell appeared in </s>
# (-15.72): <s> find russian movies </s>
# (-54.79): <s> show me the movie pretty women <unk> i can see who starred in the movie </s>
# (-6.14): <s> <unk> </s>
# (-18.13): <s> the movie is called big </s>
# (-21.16): <s> will smith <unk> <unk> </s>
# (-34.72): <s> how many movies did <unk> <unk> do </s>
# (-17.81): <s> movies and gross <unk> </s>
# (-28.99): <s> search for <unk> <unk> movies in french </s>
# (-44.34): <s> exhibit all details of original finding nemo movie </s>
# (-16.37): <s> finding nemo movie </s>
# (-19.43): <s> find the movie finding nemo </s>
# (-41.74): <s> i am looking for information on the movie finding nemo </s>
# (-30.17): <s> show me details for the movie finding nemo </s>
# (-16.18): <s> what did andrew stanton direct </s>
# (-30.04): <s> show me some other movies directed by andrew stanton </s>
# (-13.44): <s> display albert brooks movie </s>
# (-49.54): <s> show a movie with albert brooks in the cast </s>
# (-26.71): <s> what other films has sergio leone directed </s>
# (-19.03): <s> what movies has george harrison produced </s>
# (-20.01): <s> what has charlie sheen starred in </s>
# (-37.05): <s> please find the movies in which clive owen has appeared </s>
# (-32.43): <s> in which movies has clive owen <unk> </s>
# (-24.41): <s> spike lee directed what movie </s>
# (-32.46): <s> search for movies directed by spike lee </s>
# (-20.07): <s> movie release <unk> </s>
# (-14.97): <s> director information for movies </s>
# (-16.76): <s> movies by director </s>
# (-37.94): <s> please list all movies not rated pg </s>
# (-7.24): <s> find movies </s>
# (-23.48): <s> i want a list of english speaking movies </s>
# (-31.80): <s> a list of movies made in america </s>
# (-45.33): <s> are there any movies produced in the united states </s>
# (-9.57): <s> show english movies </s>
# (-11.14): <s> search english movies </s>
# (-4.80): <s> comedy </s>
# (-16.88): <s> find a comedy </s>
# (-13.81): <s> watch comedy movies </s>
# (-13.43): <s> get horror films </s>
# (-16.71): <s> show me horror movies </s>
# (-27.49): <s> i want to see a listing of horror movies </s>
# (-15.55): <s> show actor bruce willis movies </s>
# (-26.93): <s> which movies did bruce willis star in </s>
# (-28.39): <s> list movies with bruce willis </s>
# (-23.89): <s> show me movies made in canada </s>
# (-21.87): <s> can i watch a canadian film </s>
# (-12.78): <s> see canadian movies </s>
# (-27.54): <s> search for information about canadian movies </s>
# (-38.81): <s> I 'd like to see some italian films </s>
# (-7.85): <s> show me something italian - made </s>
# (-33.81): <s> i want to see a movie from spain </s>
# (-18.76): <s> find movies from spain </s>
# (-1.83): <s> spain country movies </s>
# (-25.78): <s> display a list of spanish films </s>
# (-24.38): <s> spanish movie listing </s>
# (-12.65): <s> spanish movies </s>
# (-21.40): <s> find actors in movies </s>
# (-12.89): <s> search by actors </s>
# (-20.71): <s> find some romantic movies </s>
# (-30.44): <s> i want to see a movie in french </s>
# (-13.31): <s> <unk> <unk> movies </s>
# (-25.30): <s> find movies with quentin <unk> as director </s>
# (-15.67): <s> england movies </s>
# (-24.37): <s> england movies please </s>
# (-16.93): <s> find <unk> <unk> movies </s>
# (-24.00): <s> show me what richard lester directed </s>
# (-28.28): <s> get films in hindi </s>
# (-20.81): <s> show me movies from india </s>
# (-18.82): <s> what is a british horror movie </s>
# (-31.80): <s> i want to watch an r rated comedy </s>
# (-23.96): <s> list of french language comedies </s>
# (-44.70): <s> look for dirty dancing movie with jennifer grey </s>
# (-42.19): <s> tell me in detail about the movie dirty dancing </s>
# (-27.97): <s> tell about movie dirty dancing </s>
# (-32.74): <s> can i see a list of bette midler movies </s>
# (-20.16): <s> list of movies starring bette midler </s>
# (-30.22): <s> show me all of anne hathaway 's movies </s>
# (-18.04): <s> what movies has sandra bullock produced </s>
# (-19.72): <s> find me movies from <unk> </s>
# (-27.51): <s> what movies has robert redford been in </s>
# (-13.97): <s> dirty dancing info </s>
# (-13.08): <s> dirty dancing </s>
# (-28.23): <s> give a short bio for dirty dancing </s>
# (-12.49): <s> about dirty dancing </s>
# (-17.01): <s> movies from japan </s>
# (-19.68): <s> show movies from japan </s>
# (-9.95): <s> list japanese movies </s>
# (-16.27): <s> show me japanese movies </s>
# (-31.69): <s> give me a list of some japanese movies </s>
# (-28.05): <s> give me a list of japanese movies </s>
# (-13.33): <s> japanese movies </s>
# (-16.89): <s> show me japanese language movies </s>
# (-33.88): <s> which films are spoken in japanese </s>
# (-5.50): <s> miramax films only </s>
# (-16.04): <s> show movies by miramax </s>
# (-17.07): <s> search sandra bullock movies </s>
# (-19.05): <s> watch sandra bullock movies </s>
# (-21.29): <s> find movies about vampires </s>
# (-18.12): <s> find movies having vampires </s>
# (-18.41): <s> will smith movies </s>
# (-2.56): <s> cars movie </s>
# (-19.68): <s> what movies did darla anderson produce </s>
# (-34.05): <s> what films are made by paramount </s>
# (-20.93): <s> show me movies by paramount </s>
# (-11.55): <s> what movies has paramount released </s>
# (-25.30): <s> show all movies from turkey </s>
# (-29.55): <s> show me movies produced by bruce lee </s>
# (-28.82): <s> is parenthood a drama </s>
# (-29.89): <s> i want to see an kevin james film <unk> </s>
# (-25.62): <s> find films from china </s>
# (-27.84): <s> get films from china </s>
# (-48.69): <s> i 'd like to watch a movie made in china </s>
# (-27.96): <s> list some movies from china </s>
# (-2.95): <s> chinese films </s>
# (-17.80): <s> show me other chinese movies </s>
# (-17.80): <s> show me chinese movies </s>
# (-30.80): <s> what movies have a pg-13 rating </s>
# (-35.04): <s> please list movies that are rated pg-13 </s>
# (-52.63): <s> i need a g rating <unk> i can take the kids </s>
# (-25.63): <s> find a g rated movie </s>
# (-9.30): <s> find g movies </s>
# (-9.30): <s> find g movies </s>
# (-15.86): <s> i want rated g movies </s>
# (-18.48): <s> look up g rated movies </s>
# (-55.80): <s> i am searching for any g rated movies for my children to view </s>
# (-27.94): <s> rated g movies for family watching </s>
# (-13.24): <s> find g rated movies </s>
# (-31.30): <s> are there any movies rated g playing </s>
# (-27.17): <s> i want to see movies rated g </s>
# (-17.85): <s> find movies rated g </s>
# (-24.39): <s> show me movies with g rating </s>
# (-39.63): <s> did robert wise direct any other <unk> </s>
# (-29.00): <s> bruce lee produced movie listing </s>
# (-42.42): <s> what was the last movie made by robert wise </s>
# (-24.52): <s> find movies produced by mgm </s>
# (-12.04): <s> show me british made movies </s>
# (-23.82): <s> movies from the uk </s>
# (-29.30): <s> find me movies from the uk </s>
# (-35.61): <s> can you list ron howard movie production </s>
# (-43.17): <s> i need to know the movies produce by ron howard </s>
# (-53.65): <s> did clint eastwood direct any other movies <unk> million <unk> <unk> </s>
# (-25.09): <s> find movies directed by clint eastwood </s>
# (-36.42): <s> what movies have been directed by clint eastwood </s>
# (-41.95): <s> list all movies that were directed by clint eastwood </s>
# (-16.69): <s> what movies has clint eastwood directed </s>
# (-26.32): <s> show movies directed by clint eastwood </s>
# (-27.32): <s> find all films by <unk> <unk> </s>
# (-61.14): <s> i want to select the option to search for movies produced by stephen spielberg </s>
# (-41.94): <s> i would like to search for movies produced by stephen <unk> </s>
# (-17.11): <s> show me japanese horror movies </s>
# (-33.49): <s> i would like to see movies ron howard directed </s>
# (-20.15): <s> movies by stephen spielberg </s>
# (-20.15): <s> movies by stephen spielberg </s>
# (-30.29): <s> what movies did stephen spielberg direct </s>
# (-19.57): <s> list steven spielberg movies </s>
# (-18.32): <s> steven spielberg movie </s>
# (-24.58): <s> steven spielberg movies please </s>
# (-13.17): <s> directed by steven spielberg </s>
# (-15.46): <s> find the steven spielberg movies </s>
# (-15.13): <s> find movies from steven spielberg </s>
# (-50.89): <s> i would like to watch a movie directed by eddie murphy </s>
# (-10.58): <s> the <unk> </s>
# (-29.21): <s> watch sandra bullock the blind side </s>
# (-27.37): <s> i want to see movies with <unk> <unk> </s>
# (-19.57): <s> list movies with kevin <unk> </s>
# (-23.87): <s> look for movies from france </s>
# (-40.87): <s> can you show me movies that were made in france </s>
# (-36.72): <s> find me any movies that were made in france </s>
# (-22.80): <s> french movies please </s>
# (-14.10): <s> french movies </s>
# (-17.95): <s> find movies produced by </s>
# (-13.67): <s> movies by producers </s>
# (-22.45): <s> display movies produced by </s>
# (-23.71): <s> find movies produced by mosfilm </s>
# (-30.03): <s> what was kristen stewart 's first movie </s>
# (-25.31): <s> get me movies directed by <unk> july </s>
# (-17.33): <s> tom hanks movies </s>
# (-22.88): <s> show me movies with tom hanks </s>
# (-51.61): <s> i am <unk> to find a list of movies with tom hanks </s>
# (-34.81): <s> provide movies directed by oliver stone please </s>
# (-40.49): <s> i want to look for movies produced by albert ruddy </s>
# (-42.25): <s> what are all of the movies produced by albert ruddy </s>
# (-28.15): <s> movies produced by yash chopra </s>
# (-12.33): <s> what did brad pitt <unk> </s>
# (-38.06): <s> bring up all brad pitt produced movies </s>
# (-25.57): <s> show all movies that <unk> <unk> directed </s>
# (-48.17): <s> i need a list of all the movies directed by james cameron </s>
# (-47.70): <s> give me a list of all the movies directed by james cameron </s>
# (-17.91): <s> james cameron movies produced </s>
# (-24.05): <s> movies produced by james cameron </s>
# (-32.27): <s> what films have been produced by warner bros. </s>
# (-28.87): <s> find movies produced by warner bros. </s>
# (-34.67): <s> what movies have been produced by warner bros. </s>
# (-16.55): <s> show me movies by wb </s>
# (-25.81): <s> give me information about finding nemo </s>
# (-24.31): <s> i want information about finding nemo </s>
# (-14.94): <s> show me finding nemo </s>
# (-10.61): <s> finding nemo <unk> </s>
# (-9.24): <s> search finding nemo </s>
# (-23.72): <s> show information page for finding nemo </s>
# (-13.91): <s> the campaign information </s>
# (-31.29): <s> more information on <unk> thirteen </s>
# (-11.95): <s> <unk> apollo thirteen </s>
# (-37.00): <s> has kristen stewart starred in movies other than twilight </s>
# (-16.08): <s> show me kristen stewart movies </s>
# (-21.34): <s> what movies has kristen <unk> starred in </s>
# (-13.68): <s> lionsgate movies </s>
# (-15.35): <s> show lionsgate movies </s>
# (-31.71): <s> show movies made by production lionsgate </s>
# (-22.82): <s> give me something by charles vidor </s>
# (-9.29): <s> show charles vidor movie </s>
# (-16.67): <s> what film did charles vidor direct </s>
# (-52.17): <s> which movies have been made outside the united states </s>
# (-17.78): <s> find me <unk> movies </s>
# (-12.70): <s> display 7 arts movies </s>
# (-15.31): <s> korean movie </s>
# (-38.13): <s> what other movies did <unk> <unk> star in </s>
# (-40.47): <s> i want to see movies starring denzel washington please </s>
# (-17.33): <s> list the kareena 's movie </s>
# (-37.14): <s> i want to watch a drama made in turkey </s>
# (-27.70): <s> jennifer <unk> played in what movies </s>
# (-41.21): <s> show me all of the movies directed by woody allen </s>
# (-14.15): <s> show robert wise movies </s>
# (-24.17): <s> want to see robert wise movies </s>
# (-22.83): <s> what movies has robert wise directed </s>
# (-23.96): <s> what movies have robert wise directed </s>
# (-49.80): <s> where can i find a list of movies produced by chris <unk> </s>
# (-25.72): <s> what movies has brad pitt been in </s>
# (-29.65): <s> what are the movies brad pitt had been in </s>
# (-29.44): <s> what are some movies with brad pitt </s>
# (-19.78): <s> find an r rated movie </s>
# (-19.88): <s> show me r rated movies </s>
# (-32.06): <s> give me a list of r rated movies </s>
# (-23.90): <s> look up r rated movies </s>
# (-21.62): <s> i want only r rated movies </s>
# (-29.78): <s> i want to see a list of rated r movies </s>
# (-42.92): <s> show me only movies with a rating of r </s>
# (-38.55): <s> please look for movies with an r rating </s>
# (-19.33): <s> show me movies rated r </s>
# (-33.00): <s> look for movies with an r rating </s>
# (-43.02): <s> give me a list of all movies that are rated r </s>
# (-26.39): <s> i want to watch movies from norway </s>
# (-36.34): <s> can i have a list of spanish speaking movies </s>
# (-19.34): <s> show me movies made in <unk> </s>
# (-16.26): <s> show me the movie <unk> zombies </s>
# (-31.38): <s> what movies have zombies in them </s>
# (-19.02): <s> show me movies about zombies </s>
# (-19.02): <s> show me movies about zombies </s>
# (-24.01): <s> show me <unk> by <unk> <unk> </s>
# (-14.98): <s> show ridley scott 's <unk> </s>
# (-10.36): <s> find ridley scott movies </s>
# (-38.40): <s> can you show me movies directed by ridley scott </s>
# (-11.90): <s> list german movies </s>
# (-15.68): <s> german movies </s>
# (-12.17): <s> find action films </s>
# (-15.27): <s> find some action movies </s>
# (-12.62): <s> list dredd movie </s>
# (-10.35): <s> show me george lucas movies </s>
# (-27.17): <s> find movies directed by george lucas </s>
# (-8.87): <s> produced by </s>
# (-33.95): <s> please find movies produced by morgan freeman </s>
# (-40.26): <s> please look up movies produced by morgan freeman </s>
# (-31.87): <s> search for movies produced by morgan freeman </s>
# (-27.40): <s> find movies produced by morgan freeman </s>
# (-34.71): <s> look up movies produced by morgan freeman </s>
# (-27.00): <s> what movies has meryl streep starred in </s>
# (-40.13): <s> show me the movies directed by the director of this movie </s>
# (-33.48): <s> i want to see movies made in russia </s>
# (-17.48): <s> look up star wars four movie </s>
# (-57.08): <s> display all details about star wars - a new hope movie </s>
# (-56.89): <s> get all details about star wars - a new hope movie </s>
# (-24.02): <s> star wars episode four </s>
# (-22.17): <s> i want star wars four main page </s>
# (-14.84): <s> search star wars four </s>
# (-38.52): <s> find me <unk> of info related to star wars four </s>
# (-32.52): <s> get details of in july movie </s>
# (-24.77): <s> find details of in july movie </s>
# (-30.84): <s> show details of in july movie </s>
# (-30.80): <s> tell me about in july movie </s>
# (-25.92): <s> look up the movie in july </s>
# (-38.92): <s> display information for the movie title in july </s>
# (-14.93): <s> movie in july <unk> </s>
# (-40.29): <s> where can i find the movie aankhen in hindi </s>
# (-16.35): <s> display <unk> <unk> films </s>
# (-42.95): <s> list the movies that have the actress angelina jolie </s>
# (-13.31): <s> <unk> <unk> movies </s>
# (-27.10): <s> what movies did <unk> <unk> direct </s>
# (-43.07): <s> i would like to view movies produced by clint eastwood </s>
# (-27.26): <s> list all movies about horses </s>
# (-22.69): <s> find all <unk> <unk> movies </s>
# (-17.36): <s> search by director </s>
# (-17.36): <s> search by director </s>
# (-40.35): <s> is there any upcoming movies from warner brothers </s>
# (-41.75): <s> bring up movies with ice skating in it </s>
# (-24.64): <s> find <unk> released comedies from england </s>
# (-39.48): <s> i need info on house at the end of the street </s>
# (-32.09): <s> what is the <unk> at the end of the street about </s>
# (-65.98): <s> give me more facts about the movie house at the end of the street in detail </s>
# (-65.06): <s> i would like to know in detail about the movie house at the end of the street </s>
# (-45.77): <s> display movie information for the film house at the end of the street </s>
# (-17.03): <s> films with chinese </s>
# (-35.31): <s> i want to watch a movie in chinese </s>
# (-27.85): <s> find movies produced and directed by tyler perry </s>
# (-26.91): <s> tom cruise movies please </s>
# (-25.18): <s> i want tom cruise movies please </s>
# (-17.40): <s> which movies star tom cruise </s>
# (-27.78): <s> which movies do tom cruise play in </s>
# (-17.19): <s> find end of watch </s>
# (-13.78): <s> search by genre </s>
# (-36.52): <s> looking for movies of yash chopra </s>
# (-29.28): <s> find me information about the campaign movie </s>
# (-27.28): <s> information for movie the campaign </s>
# (-30.09): <s> show me info on the movie the campaign please </s>
# (-43.25): <s> i need to see all the details about the movie the campaign </s>
# (-18.85): <s> sort all pg movies </s>
# (-17.54): <s> pg rated movies </s>
# (-35.51): <s> <unk> a list of pg movies please </s>
# (-27.97): <s> give me a list of pg movies </s>
# (-54.20): <s> can you find me a list of pg rated movies to watch </s>
# (-28.37): <s> show me a list of pg rated movies </s>
# (-26.56): <s> find movies with a pg rating </s>
# (-19.30): <s> what movies are pg </s>
# (-21.82): <s> movies by alfred hitchcock </s>
# (-22.76): <s> what movies did alfred hitchcock make </s>
# (-11.99): <s> watch <unk> movies </s>
# (-41.44): <s> i want to see any current movies starring tom hanks </s>
# (-38.52): <s> i want a list of recent movies rated pg </s>
# (-38.77): <s> give me a list of recent movies rated pg </s>
# (-26.99): <s> ray stark produced what other movies </s>
# (-23.00): <s> what is spielberg 's latest movie </s>
# (-31.60): <s> please find movies directed by tom hanks </s>
# (-32.21): <s> are there any recent movies that are polish speaking </s>
# (-33.59): <s> what movies has tom cruise been in <unk> </s>
# (-19.99): <s> search for new movies </s>
# (-18.63): <s> search for in july </s>
# (-11.20): <s> watch in july <unk> </s>
# (-24.63): <s> search for information about lionsgate </s>
# (-17.09): <s> lionsgate info </s>
# (-28.04): <s> find information about paramount studios </s>
# (-21.91): <s> who is ray stark </s>
# (-20.90): <s> find information on charles vidor </s>
# (-37.84): <s> i want to look up information about tom cruise </s>
# (-32.76): <s> can you please search details about will ferrell </s>
# (-20.18): <s> will ferrell biography </s>
# (-23.48): <s> show will ferrell biography </s>
# (-24.47): <s> show me a complete biography of will ferrell </s>
# (-23.44): <s> show me information on will ferrell </s>
# (-23.83): <s> show me will ferrell 's bio </s>
# (-23.27): <s> get info on kristen stewart </s>
# (-25.46): <s> does kristen stewart have a <unk> page </s>
# (-39.29): <s> where can i find information about kristen stewart </s>
# (-18.70): <s> jennifer <unk> bio </s>
# (-38.63): <s> i want to see spielberg 's main page </s>
# (-11.32): <s> steven spielberg <unk> </s>
# (-18.14): <s> about steven spielberg </s>
# (-29.36): <s> find me bio details for steven spielberg </s>
# (-25.33): <s> bio for steven spielberg </s>
# (-12.07): <s> show me alfred hitchcock </s>
# (-35.74): <s> i want more information about alfred <unk> 's biography </s>
# (-17.17): <s> all info hitchcock </s>
# (-32.59): <s> find the name of the producer of avatar </s>
# (-9.54): <s> producer hitch </s>
# (-11.93): <s> who produces hitch </s>
# (-28.87): <s> production company for transformers </s>
# (-18.36): <s> what company made et </s>
# (-35.56): <s> what was the production company for et </s>
# (-12.73): <s> who produces cars </s>
# (-30.82): <s> can you find who produced cars </s>
# (-16.94): <s> production company for devil </s>
# (-22.14): <s> who produced the movie steel magnolias </s>
# (-14.31): <s> who produced avatar </s>
# (-31.69): <s> i want to know the producer of avatar </s>
# (-14.31): <s> who produced avatar </s>
# (-14.31): <s> who produced avatar </s>
# (-10.97): <s> avatar producer </s>
# (-35.78): <s> i would like to know who produced the movie avatar </s>
# (-18.78): <s> who produced the movie avatar </s>
# (-34.83): <s> who are the producers for the movie avatar </s>
# (-21.06): <s> what is grease 's producer </s>
# (-10.75): <s> who produced grease </s>
# (-38.14): <s> who produced the movie my big fat greek wedding </s>
# (-17.20): <s> who produced pretty woman </s>
# (-31.45): <s> tell me the producer for the godfather </s>
# (-25.40): <s> the godfather was produced by </s>
# (-17.36): <s> who produced the movie <unk> </s>
# (-23.25): <s> who produced hotel rwanda </s>
# (-21.76): <s> who produced marley and me </s>
# (-23.36): <s> who produced <unk> me </s>
# (-41.42): <s> who is the company that produced the movie inception </s>
# (-27.04): <s> what company <unk> the movie inception </s>
# (-31.38): <s> find producer of the great debaters </s>
# (-11.72): <s> who produced inception </s>
# (-48.66): <s> provide the name of the company that produced sparkle </s>
# (-42.58): <s> i need to know the company that produced sparkle </s>
# (-27.10): <s> find the producer of look who 's <unk> </s>
# (-15.95): <s> who produced <unk> <unk> </s>
# (-28.48): <s> find the producer of step up </s>
# (-35.40): <s> please find the producer of freedom writers </s>
# (-32.96): <s> look for the producer of freedom writers </s>
# (-18.47): <s> show me movie rating </s>
# (-30.53): <s> how much revenue did pretty woman make </s>
# (-22.66): <s> earnings for pretty woman </s>
# (-28.07): <s> what was the revenue of pretty woman </s>
# (-24.80): <s> how much did pretty woman make </s>
# (-34.42): <s> what was the gross revenue for the avengers </s>
# (-21.94): <s> how much did the avengers make </s>
# (-21.73): <s> revenue for the avengers </s>
# (-41.66): <s> how much did the dark night generate in revenues </s>
# (-28.81): <s> find revenue <unk> for jurassic park </s>
# (-26.97): <s> revenue for <unk> day </s>
# (-40.06): <s> what is the new will ferrell movie about </s>
# (-27.96): <s> who played the voice of nemo in finding nemo </s>
# (-35.05): <s> who played <unk> <unk> in <unk> days </s>
# (-42.46): <s> who stars in house at the end of the street </s>
# (-48.84): <s> show me the cast for the house at the end of the street </s>
# (-46.54): <s> cast and crew of house at the end of the street </s>
# (-24.81): <s> do they speak german in the movie </s>
# (-34.86): <s> is this movie filmed in india </s>
# (-23.51): <s> show all dawn of the dead movies </s>
# (-12.71): <s> all of kung <unk> panda movies </s>
# (-26.04): <s> list movies that have time travel in their title </s>
# (-42.92): <s> i want to see nine twenty eight release date films from twenty twelve </s>
# (-17.26): <s> find information about french movies </s>
# (-66.84): <s> i need to know more about the life and movies of indian actor dilip kumar </s>
# (-26.95): <s> what does the miramax <unk> look like </s>
# (-24.41): <s> show me pictures of martin scorsese </s>
# (-20.33): <s> <unk> of steven spielberg </s>
# (-33.02): <s> i want to see images of will ferrell </s>
# (-31.00): <s> show me pictures of woody allen </s>
# (-17.73): <s> what are popular movie producers </s>
# (-25.56): <s> can you give me the producer </s>
# (-38.87): <s> i would like to know the rating of the movie avatar </s>
# (-28.77): <s> what rating is the movie barfi </s>
# (-18.18): <s> what is finding nemo rated </s>
# (-36.00): <s> i need to know the rating of grease </s>
# (-47.33): <s> can you find out what rating the movie grease is </s>
# (-23.71): <s> what is kids by <unk> <unk> rated </s>
# (-30.65): <s> what rating did marley and me receive </s>
# (-38.31): <s> what is the rating for mr and mrs smith </s>
# (-30.16): <s> what rating did resident evil receive </s>
# (-44.04): <s> rating for snow white and the huntsman </s>
# (-28.91): <s> what rating is step up </s>
# (-40.24): <s> look up the rating of the movie step up </s>
# (-40.73): <s> what rating did the campaign movie get </s>
# (-35.10): <s> show me the rating for the movie the expendables </s>
# (-32.78): <s> what is the rating for toy story </s>
# (-31.26): <s> what is the rating for the movie toy story </s>
# (-33.42): <s> rating for twilight breaking dawn </s>
# (-33.20): <s> what was gross revenue for batman begins </s>
# (-22.70): <s> how much has black swan <unk> in </s>
# (-32.50): <s> find the revenue for downton abbey </s>
# (-26.81): <s> find the revenue of <unk> <unk> <unk> </s>
# (-26.75): <s> what is the most a movie made </s>
# (-20.62): <s> reviews for dirty dancing </s>
# (-24.25): <s> find reviews for dirty dancing </s>
# (-19.37): <s> what are reviews for finding nemo </s>
# (-25.64): <s> what are the ratings and review on finding nemo </s>
# (-19.64): <s> reviews for finding nemo </s>
# (-19.64): <s> reviews for finding nemo </s>
# (-19.64): <s> reviews for finding nemo </s>
# (-17.06): <s> reviews for movie </s>
# (-21.56): <s> reviews for in july </s>
# (-43.28): <s> what are the <unk> <unk> about star wars episode four </s>
# (-30.97): <s> how long is life is beautiful </s>
# (-44.72): <s> synopsis for the movie house at the end of the street </s>
# (-28.39): <s> synopsis for star wars four </s>
# (-25.00): <s> <unk> of star wars four </s>
# (-19.53): <s> finding nemo movie <unk> </s>
# (-46.02): <s> show me the trailer for house at the end of the street </s>
# (-19.41): <s> life is <unk> <unk> </s>
# (-28.33): <s> trailer for star wars a new hope </s>
# (-22.25): <s> show resident evil movies with trailers </s>
# (-34.61): <s> can i see <unk> for upcoming warner brothers movies </s>
# (-44.22): <s> how many woody allen movies are set in new <unk> <unk> </s>
# (-32.07): <s> how many scorsese films were filmed in france </s>
